# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
from sklearn import datasets

# %%
data = pd.read_csv('dataset/diabetes-dataset.csv', header=(0))
print("Número de linhas e colunas:",data.shape)
data.dropna()
data.head(-10)
# Out:
# Número de linhas e colunas: (2000, 9)
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0               2      138             62             35        0  33.6
# 1               0       84             82             31      125  38.2
# 2               0      145              0              0        0  44.2
# 3               0      135             68             42      250  42.3
# 4               1      139             62             41      480  40.7
# ...           ...      ...            ...            ...      ...   ...
# 1985            0      131             88              0        0  31.6
# 1986            6      104             74             18      156  29.9
# 1987            3      148             66             25        0  32.5
# 1988            4      120             68              0        0  29.6
# 1989            4      110             66              0        0  31.9
#
#       DiabetesPedigreeFunction  Age  Outcome
# 0                        0.127   47        1
# 1                        0.233   23        0
# 2                        0.630   31        1
# 3                        0.365   24        1
# 4                        0.536   21        0
# ...                        ...  ...      ...
# 1985                     0.743   32        1
# 1986                     0.722   41        1
# 1987                     0.256   22        0
# 1988                     0.709   34        0
# 1989                     0.471   29        0
#
# [1990 rows x 9 columns]

# %% [markdown]
# 1) Relationship between number of pregnancies and blood pressure.

# %%
#Gráfico de dispersão
#Reta com ajustada
data = data.to_numpy()
y = data[:,2] #Blood pressure
x = data[:,0] #Pregnancies
X = np.array(x).reshape(-1, 1)
Y = np.array(y)

plt.scatter(X, Y)
plt.title("Gráfico de dispersão")
# Out:
# Text(0.5, 1.0, 'Gráfico de dispersão')

# %%
#Reta com ajustada
modelo = LinearRegression().fit(X, Y)
print(modelo.intercept_)
print (modelo.coef_)
plt.scatter(X, Y)
plt.plot(X, modelo.predict(X), color = 'red')
# Out:
# 65.9282860353243
# [0.86869555]

# %%
#Coeficiente de correlação
import numpy as np
y = data[:,2]
x = data[:,0]
correlacao = np.corrcoef(x, y)
print(correlacao)
# Out:
# [[1.         0.14967246]
#  [0.14967246 1.        ]]

# %%
#Coeficiente de Determinação R^2
from sklearn.metrics import r2_score
y_pred=modelo.predict(X)
R2 = r2_score(y, y_pred)
print('R2:', R2)
# Out:
# R2: 0.02240184463670636

# %% [markdown]
# 2) Relationship between age and BMI.

# %%
#Gráfico de dispersão
#Reta com ajustada
data = data.to_numpy()
y = data[:,5]
x = data[:,7]
X = np.array(x).reshape(-1, 1)
Y = np.array(y)

plt.scatter(X, Y)

# %%
#Reta com ajustada
modelo = LinearRegression().fit(X, Y)
print(modelo.intercept_)
print (modelo.coef_)
plt.scatter(X, Y)
plt.plot(X, modelo.predict(X), color = 'red')
# Out:
# 31.300932752690525
# [0.02695841]

# %%
#Coeficiente de correlação
import numpy as np
y = data[:,5]
x = data[:,7]
correlacao = np.corrcoef(x, y)
print(correlacao)
# Out:
# [[1.         0.03898737]
#  [0.03898737 1.        ]]

# %%
#Coeficiente de Determinação R^2
from sklearn.metrics import r2_score
y_pred=modelo.predict(X)
R2 = r2_score(y, y_pred)
print('R2:', R2)
# Out:
# R2: 0.0015200152656674737

# %% [markdown]
# 3) Relationship between outcome and DiabetesPedigreeFunction.

# %%
#Gráfico de dispersão
#Reta com ajustada
data = data.to_numpy()
x = data[:,6]
y = data[:,8]
X = np.array(x).reshape(-1, 1)
Y = np.array(y)

plt.scatter(X, Y)

# %%
#Reta com ajustada
modelo = LinearRegression().fit(X, Y)
print(modelo.intercept_)
print (modelo.coef_)
plt.scatter(X, Y)
plt.plot(X, modelo.predict(X), color = 'red')
# Out:
# 0.23463512807043962
# [0.22798478]

# %%
#Coeficiente de correlação
import numpy as np
x = data[:,6]
y = data[:,8]
correlacao = np.corrcoef(x, y)
print(correlacao)
# Out:
# [[1.         0.15545908]
#  [0.15545908 1.        ]]

# %%
#Coeficiente de Determinação R^2
from sklearn.metrics import r2_score
y_pred=modelo.predict(X)
R2 = r2_score(y, y_pred)
print('R2:', R2)
# Out:
# R2: 0.0241675252923238

# %% [markdown]
# 4) Relationship between outcome and SkinThickness.

# %%
#Gráfico de dispersão
#Reta com ajustada
data = data.to_numpy()
x = data[:,3]
y = data[:,8]
X = np.array(x).reshape(-1, 1)
Y = np.array(y)

plt.scatter(X, Y)

# %%
#Reta com ajustada
modelo = LinearRegression().fit(X, Y)
print(modelo.intercept_)
print (modelo.coef_)
plt.scatter(X, Y)
plt.plot(X, modelo.predict(X), color = 'red')
# Out:
# 0.29509299109100845
# [0.0022406]

# %%
#Coeficiente de correlação
import numpy as np
x = data[:,3]
y = data[:,8]
correlacao = np.corrcoef(x, y)
print(correlacao)
# Out:
# [[1.         0.07604025]
#  [0.07604025 1.        ]]

# %%
#Coeficiente de Determinação R^2
from sklearn.metrics import r2_score
y_pred=modelo.predict(X)
R2 = r2_score(y, y_pred)
print('R2:', R2)
# Out:
# R2: 0.005782119158622034

# %% [markdown]
# 5) Relationship between insulin and glucose.

# %%
#Gráfico de dispersão
#Reta com ajustada
data = data.to_numpy()
y = data[:,1]
x = data[:,4]
X = np.array(x).reshape(-1, 1)
Y = np.array(y)

plt.scatter(X, Y)

# %%
#Reta com ajustada
modelo = LinearRegression().fit(X, Y)
print(modelo.intercept_)
print (modelo.coef_)
plt.scatter(X, Y)
plt.plot(X, modelo.predict(X), color = 'red')
# Out:
# 113.76647132574027
# [0.09240697]

# %%
#Coeficiente de correlação
import numpy as np
y = data[:,1]
x = data[:,4]
correlacao = np.corrcoef(x, y)
print(correlacao)
# Out:
# [[1.         0.32037084]
#  [0.32037084 1.        ]]

# %%
#Coeficiente de Determinação R^2
from sklearn.metrics import r2_score
y_pred=modelo.predict(X)
R2 = r2_score(y, y_pred)
print('R2:', R2)
# Out:
# R2: 0.10263747665881362
